# %%
import pandas as pd

df = pd.read_json('test.json')

# inspect
print(df.head())
# Out:
#        id                                            context  \
# 0  da_q01  The Eiffel Tower is a wrought-iron lattice tow...
# 1  da_q02  The Moon is Earth's only natural satellite and...
# 2  da_q03  Albert Einstein was a German-born theoretical ...
# 3  da_q04  Mount Everest is Earth's highest mountain abov...
# 4  da_q05  The Amazon River flows across northern South A...
#
#                                     question question_lang  \
# 0               Hvem designede Eiffeltårnet?            da
# 1               Hvor mange måner har Jorden?            da
# 2            Hvad udviklede Albert Einstein?            da
# 3                 Hvor ligger Mount Everest?            da
# 4  Hvilket land udspringer Amazonasfloden i?            da
#
#                                            answer  \
# 0              It was designed by Gustave Eiffel.
# 1                             Earth has one moon.
# 2          He developed the theory of relativity.
# ...
